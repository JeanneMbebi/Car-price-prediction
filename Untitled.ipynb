# %%
import pandas as pd
df = pd.read_csv('CAR DETAILS FROM CAR DEKHO.csv')

# %%
df.head()
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
df.shape
# Out:
# (4340, 8)

# %%
print(df['seller_type'].unique())
# Out:
# ['Individual' 'Dealer' 'Trustmark Dealer']

# %%
print(df['transmission'].unique())
# Out:
# ['Manual' 'Automatic']

# %%
print(df['owner'].unique())
# Out:
# ['First Owner' 'Second Owner' 'Fourth & Above Owner' 'Third Owner'
#  'Test Drive Car']

# %%
print(df['fuel'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG' 'LPG' 'Electric']

# %%
# Check the missing values 
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner'],
#       dtype='object')

# %%
final_df = df[['year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
       'transmission', 'owner']]

# %%
final_df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2007          60000      70000  Petrol  Individual       Manual
# 1  2007         135000      50000  Petrol  Individual       Manual
# 2  2012         600000     100000  Diesel  Individual       Manual
# 3  2017         250000      46000  Petrol  Individual       Manual
# 4  2014         450000     141000  Diesel  Individual       Manual
#
#           owner
# 0   First Owner
# 1   First Owner
# 2   First Owner
# 3   First Owner
# 4  Second Owner

# %%
final_df['current year'] = 2020

# %%
final_df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2007          60000      70000  Petrol  Individual       Manual
# 1  2007         135000      50000  Petrol  Individual       Manual
# 2  2012         600000     100000  Diesel  Individual       Manual
# 3  2017         250000      46000  Petrol  Individual       Manual
# 4  2014         450000     141000  Diesel  Individual       Manual
#
#           owner  current year
# 0   First Owner          2020
# 1   First Owner          2020
# 2   First Owner          2020
# 3   First Owner          2020
# 4  Second Owner          2020

# %%
final_df['number of year'] = final_df['current year']-final_df['year']

# %%
final_df.head()
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2007          60000      70000  Petrol  Individual       Manual
# 1  2007         135000      50000  Petrol  Individual       Manual
# 2  2012         600000     100000  Diesel  Individual       Manual
# 3  2017         250000      46000  Petrol  Individual       Manual
# 4  2014         450000     141000  Diesel  Individual       Manual
#
#           owner  current year  number of year
# 0   First Owner          2020              13
# 1   First Owner          2020              13
# 2   First Owner          2020               8
# 3   First Owner          2020               3
# 4  Second Owner          2020               6

# %%
final_df.drop(['year'], axis = 1, inplace = True)

# %%
final_df.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0          60000      70000  Petrol  Individual       Manual   First Owner
# 1         135000      50000  Petrol  Individual       Manual   First Owner
# 2         600000     100000  Diesel  Individual       Manual   First Owner
# 3         250000      46000  Petrol  Individual       Manual   First Owner
# 4         450000     141000  Diesel  Individual       Manual  Second Owner
#
#    current year  number of year
# 0          2020              13
# 1          2020              13
# 2          2020               8
# 3          2020               3
# 4          2020               6

# %%
final_df.drop(['current year'], axis = 1, inplace = True)

# %%
final_df.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0          60000      70000  Petrol  Individual       Manual   First Owner
# 1         135000      50000  Petrol  Individual       Manual   First Owner
# 2         600000     100000  Diesel  Individual       Manual   First Owner
# 3         250000      46000  Petrol  Individual       Manual   First Owner
# 4         450000     141000  Diesel  Individual       Manual  Second Owner
#
#    number of year
# 0              13
# 1              13
# 2               8
# 3               3
# 4               6

# %%
# One hot encode 
final_df = pd.get_dummies(final_df, drop_first =  True)

# %%
final_df.head()
# Out:
#    selling_price  km_driven  number of year  fuel_Diesel  fuel_Electric  \
# 0          60000      70000              13            0              0
# 1         135000      50000              13            0              0
# 2         600000     100000               8            1              0
# 3         250000      46000               3            0              0
# 4         450000     141000               6            1              0
#
#    fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 0         0            1                       1
# 1         0            1                       1
# 2         0            0                       1
# 3         0            1                       1
# 4         0            0                       1
#
#    seller_type_Trustmark Dealer  transmission_Manual  \
# 0                             0                    1
# 1                             0                    1
# 2                             0                    1
# 3                             0                    1
# 4                             0                    1
#
#    owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                           0                   0                     0
# 1                           0                   0                     0
# 2                           0                   0                     0
# 3                           0                   0                     0
# 4                           0                   1                     0
#
#    owner_Third Owner
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
final_df.corr()
# Out:
#                               selling_price  km_driven  number of year  \
# selling_price                      1.000000  -0.192289       -0.413922
# km_driven                         -0.192289   1.000000        0.419688
# number of year                    -0.413922   0.419688        1.000000
# fuel_Diesel                        0.282947   0.285396       -0.121424
# fuel_Electric                     -0.005095  -0.001372        0.025540
# fuel_LPG                          -0.042434   0.036652        0.051266
# fuel_Petrol                       -0.269453  -0.291139        0.114908
# seller_type_Individual            -0.236798   0.182663        0.173703
# seller_type_Trustmark Dealer       0.110176  -0.089858       -0.100225
# transmission_Manual               -0.530205   0.120226        0.143800
# owner_Fourth & Above Owner        -0.078725   0.097349        0.186361
# owner_Second Owner                -0.161986   0.195203        0.292349
# owner_Test Drive Car               0.048799  -0.083445       -0.095795
# owner_Third Owner                 -0.111326   0.194713        0.244308
#
#                               fuel_Diesel  fuel_Electric  fuel_LPG  \
# selling_price                    0.282947      -0.005095 -0.042434
# km_driven                        0.285396      -0.001372  0.036652
# number of year                  -0.121424       0.025540  0.051266
# fuel_Diesel                      1.000000      -0.015063 -0.072422
# fuel_Electric                   -0.015063       1.000000 -0.001108
# fuel_LPG                        -0.072422      -0.001108  1.000000
# fuel_Petrol                     -0.970934      -0.014856 -0.071427
# seller_type_Individual          -0.035314      -0.026118  0.035122
# seller_type_Trustmark Dealer    -0.007911      -0.002355 -0.011324
# transmission_Manual             -0.048098      -0.044746  0.024764
# owner_Fourth & Above Owner      -0.021054      -0.002094  0.013384
# owner_Second Owner               0.003524       0.025960  0.030141
# owner_Test Drive Car            -0.010575      -0.000952 -0.004577
# owner_Third Owner                0.009373      -0.004166  0.004836
#
#                               fuel_Petrol  seller_type_Individual  \
# selling_price                   -0.269453               -0.236798
# km_driven                       -0.291139                0.182663
# number of year                   0.114908                0.173703
# fuel_Diesel                     -0.970934               -0.035314
# fuel_Electric                   -0.014856               -0.026118
# fuel_LPG                        -0.071427                0.035122
# fuel_Petrol                      1.000000                0.029845
# seller_type_Individual           0.029845                1.000000
# seller_type_Trustmark Dealer     0.012489               -0.266904
# transmission_Manual              0.039614                0.214163
# owner_Fourth & Above Owner       0.011502                0.072322
# owner_Second Owner              -0.012717                0.186573
# owner_Test Drive Car             0.012427               -0.107886
# owner_Third Owner               -0.008502                0.140823
#
#                               seller_type_Trustmark Dealer  \
# selling_price                                     0.110176
# km_driven                                        -0.089858
# number of year                                   -0.100225
# fuel_Diesel                                      -0.007911
# fuel_Electric                                    -0.002355
# fuel_LPG                                         -0.011324
# fuel_Petrol                                       0.012489
# seller_type_Individual                           -0.266904
# seller_type_Trustmark Dealer                      1.000000
# transmission_Manual                              -0.042346
# owner_Fourth & Above Owner                       -0.021395
# owner_Second Owner                               -0.076764
# owner_Test Drive Car                             -0.009729
# owner_Third Owner                                -0.042578
#
#                               transmission_Manual  owner_Fourth & Above Owner  \
# selling_price                           -0.530205                   -0.078725
# km_driven                                0.120226                    0.097349
# number of year                           0.143800                    0.186361
# fuel_Diesel                             -0.048098                   -0.021054
# fuel_Electric                           -0.044746                   -0.002094
# fuel_LPG                                 0.024764                    0.013384
# fuel_Petrol                              0.039614                    0.011502
# seller_type_Individual                   0.214163                    0.072322
# seller_type_Trustmark Dealer            -0.042346                   -0.021395
# transmission_Manual                      1.000000                    0.035597
# owner_Fourth & Above Owner               0.035597                    1.000000
# owner_Second Owner                       0.068068                   -0.080648
# owner_Test Drive Car                     0.009152                   -0.008648
# owner_Third Owner                        0.030802                   -0.037849
#
#                               owner_Second Owner  owner_Test Drive Car  \
# selling_price                          -0.161986              0.048799
# km_driven                               0.195203             -0.083445
# number of year                          0.292349             -0.095795
# fuel_Diesel                             0.003524             -0.010575
# fuel_Electric                           0.025960             -0.000952
# fuel_LPG                                0.030141             -0.004577
# fuel_Petrol                            -0.012717              0.012427
# seller_type_Individual                  0.186573             -0.107886
# seller_type_Trustmark Dealer           -0.076764             -0.009729
# transmission_Manual                     0.068068              0.009152
# owner_Fourth & Above Owner             -0.080648             -0.008648
# owner_Second Owner                      1.000000             -0.036672
# owner_Test Drive Car                   -0.036672              1.000000
# owner_Third Owner                      -0.160498             -0.017210
#
#                               owner_Third Owner
# selling_price                         -0.111326
# km_driven                              0.194713
# number of year                         0.244308
# fuel_Diesel                            0.009373
# fuel_Electric                         -0.004166
# fuel_LPG                               0.004836
# fuel_Petrol                           -0.008502
# seller_type_Individual                 0.140823
# seller_type_Trustmark Dealer          -0.042578
# transmission_Manual                    0.030802
# owner_Fourth & Above Owner            -0.037849
# owner_Second Owner                    -0.160498
# owner_Test Drive Car                  -0.017210
# owner_Third Owner                      1.000000

# %%
import seaborn as sns

# %%
sns.pairplot(final_df)

# %%
import matplotlib.pyplot as plt
corr_mat = final_df.corr()
top_corr_features = corr_mat.index
plt.figure(figsize = (20,20))
g =  sns.heatmap(final_df[top_corr_features].corr(), annot = True)

# %%
final_df.head()
# Out:
#    selling_price  km_driven  number of year  fuel_Diesel  fuel_Electric  \
# 0          60000      70000              13            0              0
# 1         135000      50000              13            0              0
# 2         600000     100000               8            1              0
# 3         250000      46000               3            0              0
# 4         450000     141000               6            1              0
#
#    fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 0         0            1                       1
# 1         0            1                       1
# 2         0            0                       1
# 3         0            1                       1
# 4         0            0                       1
#
#    seller_type_Trustmark Dealer  transmission_Manual  \
# 0                             0                    1
# 1                             0                    1
# 2                             0                    1
# 3                             0                    1
# 4                             0                    1
#
#    owner_Fourth & Above Owner  owner_Second Owner  owner_Test Drive Car  \
# 0                           0                   0                     0
# 1                           0                   0                     0
# 2                           0                   0                     0
# 3                           0                   0                     0
# 4                           0                   1                     0
#
#    owner_Third Owner
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
# defining target and features
X = final_df.iloc[:,1:]
y = final_df.iloc[:,0]

# %%
y
# Out:
# 0        60000
# 1       135000
# 2       600000
# 3       250000
# 4       450000
#          ...
# 4335    409999
# 4336    409999
# 4337    110000
# 4338    865000
# 4339    225000
# Name: selling_price, Length: 4340, dtype: int64

# %%
# Feature importance
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [2.47356134e-01 2.49567743e-01 1.28823597e-01 4.04882435e-05
#  2.51063224e-05 2.22315142e-04 4.71402338e-02 8.11527107e-03
#  2.92832605e-01 7.54023907e-04 2.04620307e-02 7.21577030e-04
#  3.93887455e-03]

# %%
feature_importance = pd.Series(model.feature_importances_ , index =  X.columns)
feature_importance.nlargest(5).plot(kind = 'barh')
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =  train_test_split(X,y, test_size=0.2)

# %%
X_train.shape
# Out:
# (3472, 13)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF = RandomForestRegressor()

# %%
# hyperparameters
import numpy as np

# number of trees in the random forest
n_estimators = [int(x) for x in np.linspace(start=100, stop = 1200, num = 12)]
# number of features to consider at every split
max_features = ['auto', 'sqrt']
# maximum number of levels in the tree
max_depth = [int(x) for x in np.linspace(5, 30, num=6)]
# max_depth.append (none)
# minimum number of sample required to split a node
min_sample_split = [2,5,15, 100]
# minimum number of sample required at each leaf node
min_sample_leaf = [1,2,5,10]

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Create the random Grid
random_grid = {'n_estimators':n_estimators,
              'max_features': max_features,
              'max_depth': max_depth,
              'min_samples_split': min_sample_split,
              'min_samples_leaf':min_sample_leaf}
print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# Use random grid to select the best hyperparameters
# Initializing a random regressor

rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, cv =5, scoring = 'neg_mean_squared_error', n_iter = 10, verbose = 2, random_state = 42, n_jobs = 1, error_score = 'raise')

# %%
rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=900; total time=   2.5s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=900; total time=   2.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=900; total time=   2.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=900; total time=   2.1s
# [CV] END max_depth=15, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=900; total time=   2.0s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=1100; total time=   2.5s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=1100; total time=   2.5s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=1100; total time=   2.5s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=1100; total time=   2.5s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=5, min_samples_split=100, n_estimators=1100; total time=   2.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=10, min_samples_split=15, n_estimators=300; total time=   0.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=400; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=400; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=400; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=400; total time=   0.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=400; total time=   0.6s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=700; total time=   2.1s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=700; total time=   2.3s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=700; total time=   2.7s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=700; total time=   2.6s
# [CV] END max_depth=25, max_features=auto, min_samples_leaf=5, min_samples_split=2, n_estimators=700; total time=   2.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   2.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   2.1s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   2.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   2.0s
# [CV] END max_depth=30, max_features=sqrt, min_samples_leaf=2, min_samples_split=2, n_estimators=1000; total time=   2.0s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1100; total time=   3.1s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1100; total time=   3.2s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1100; total time=   3.7s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1100; total time=   5.4s
# [CV] END max_depth=10, max_features=auto, min_samples_leaf=2, min_samples_split=15, n_estimators=1100; total time=   6.6s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=   1.5s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=   1.3s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=   0.9s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=   0.8s
# [CV] END max_depth=20, max_features=auto, min_samples_leaf=2, min_samples_split=100, n_estimators=300; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=700; total time=   1.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=700; total time=   1.0s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=700; total time=   1.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=700; total time=   1.6s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=700; total time=   1.5s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=700; total time=   1.8s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=700; total time=   1.2s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=700; total time=   1.3s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=700; total time=   1.9s
# [CV] END max_depth=20, max_features=sqrt, min_samples_leaf=5, min_samples_split=100, n_estimators=700; total time=   1.4s
# RandomizedSearchCV(cv=5, error_score='raise', estimator=RandomForestRegressor(),
#                    n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 15, 100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
#         160110.7948323 ,  161669.70170051,  279113.92339339,
#         289188.34914105,  703816.54035723,  519377.25530478,
#         845247.74766077,  216958.55993632,  578159.63376836,
#         892102.21997749,  821124.88725387,  721124.19950452,
#         636047.21357709,  401253.51183416,  168481.25877984,
#         208313.57423097,  176782.56965966,  265822.77950409,
#         883155.174348  ,  959382.85943487,  271937.81195235,
#         162022.81767028,  479268.93963968,  448548.90572553,
#        1148890.66847065,  122771.14226564,  416033.38684744,
#         125044.93904342, 1015941.53189762,  842160.10651413,
#         354669.65296063,  233636.16427556,  151417.51274452,
#         266637.98378796,  246761.6793349 ,  118053.8389643 ,
#        1452835.87008087,  737891.38977411,  201938.45745368,
#         635523.05249495,  349355.40772736,  227149.82029072,
#         314850.67168095,  290346.32998387,  188960.01466473,
#         280901.77770478, 1882352.80873065,  342281.15283574,
#         578485.51560721,  331276.95065243,  322477.74294864,
#         422979.72102341,  225627.87858051,  135154.2405609 ,
#         335877.99155381,  200178.1463093 ,  279968.43752397,
#         452768.05738355,  817430.39671267,  423888.76304617,
#         376535.84167878,  848311.29494302,  121744.04723741,
#         825873.99477408,  564294.23701995,  297703.13980958,
#         419776.1316835 ,  328700.40235124,  297997.00148006,
#         359666.06447959,  323460.27323887,  298632.72378923,
#         592262.72966161,  172654.83121187,  283529.19982682,
#         328567.50893923,  451698.67983047,  227812.48513799,
#         135154.2405609 ,  308491.29741716,  156124.07448023,
#        1028335.70475215,  318176.47371935,  607522.16676748,
#         468315.64819502,  239709.00162794,  343833.25055699,
#         111624.83696423,  578485.51560721,  387267.3903121 ,
#        1050396.71706648,  194676.51109207,  312285.07682049,
#         121033.84626399,  427437.33743222,  123107.40452129,
#         495134.35789756,  578485.51560721,  192570.25654812,
#         430072.73070265, 2184885.66369868,  169916.23597418,
#         515686.48284069, 1584468.1808386 ,  235591.38284148,
#         309490.53573036,  415372.88264906,  202629.09220279,
#         283572.6603058 ,  107685.45214788,  598065.22208993,
#         552006.18254121, 1993160.79601056,  191400.3685152 ,
#         195426.29960276,  338463.94695673,  843657.32626187,
#         455987.48141505,  651792.48087359,  428524.66920457,
#         453459.52197031,  197903.66188786,  129028.99964935,
#         521068.33775115,  488133.34270118,  239709.00162794,
#         299884.25760801,  192383.11310588,  480038.18346334,
#         227812.48513799,  450394.91355982,  620366.37864567,
#         455520.61653616,  182104.26599271,  123828.61407608,
#        1315689.87615042,  838602.9841796 ,  548552.97322292,
#         246514.17919879, 1828662.66327885,  206547.21076588,
#         951310.64620642,  709175.27486626,  499614.9343181 ,
#        1346349.38915425,  338102.15603384,  449494.69200505,
#         533464.28013629,  516901.90377219,  333637.65459027,
#         189939.5045668 ,  629521.15910464,  646599.84854642,
#         188473.06026951])

# %%
sns.histplot(y_test-prediction)
# Out:
# <AxesSubplot:xlabel='selling_price', ylabel='Count'>

# %%
plt.scatter(y_test, prediction)

# %%
## Deployment

import pickle 

# open a file where you want to store the data
file = open('randomforest_regressionmodel.plk', 'wb')
 # drop (dump) information to that file
    
pickle.dump(rf_random, file)

# %%
rf_random.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9016/1334248109.py in <module>
# ----> 1 rf_random.fit(X_train, y_train)
#
# NameError: name 'rf_random' is not defined
